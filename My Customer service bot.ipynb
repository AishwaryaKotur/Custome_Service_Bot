# %%
def cs_service_bot():
    print("Hello! Welcome to the DNS Cable Company's Service Portal. Are you a new or existing customer?")
    print("[1] New Customer\n[2] Existing Customer")
    try:
        userChoice = int(input("Please enter the number corresponding to your choice: "))
        print("\n\n :------     customer bot at your service     :--------\n\n")
        if int(userChoice) == 1:
            new_customer()
        elif int(userChoice) == 2:
            existing_customer()
        else:
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~ Sorry, we didn't understand your selection. ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("Try again.....")
            cs_service_bot()

    except ValueError:
        print("\t\t\t\t\t\t\tSorry...Invalid request!!!\n\n")
        cs_service_bot()

# %%
def new_customer():
    print("We're excited to have you join the DNS family, how can we help you?\n\n")
    print("\t\t\t[1] Sign up for service.\n\t\t\t[2] Schedule a home visit.\n\t\t\t[3] Speak to a sales representative.")
    try:
        newUserChoice = int(input(">>>>> "))
        print("\n")
        if newUserChoice == 1:
            sign_up()
        elif newUserChoice == 2:
            home_visit()
        elif newUserChoice == 3:
            live_rep("sales")
        else:
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~ Sorry, we didn't understand your selection. ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("Try again.....")
            new_customer()
    except ValueError:
        print("\t\t\t\t\t\t\tSorry...Invalid request!!!\n\n")
        new_customer()

# %%
def existing_customer():
    print("\t\t\t[1] Television Support\n\t\t\t[2] Internet Support\n\t\t\t[3] Speak to a support representative.\n")
    print("What kind of support do you need?\n")
    try:
        exUserChoice = int(input("\t\t >>>>> "))
        if exUserChoice == 1:
            television_support()
        elif exUserChoice == 2:
            internet_support()
        elif exUserChoice == 3:
            live_rep("support")
        else:
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~ Sorry, we didn't understand your selection. ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("Try again.....")
            existing_customer()
    except ValueError:
        print("\t\t\t\t\t\t\tSorry...Invalid request!!!\n\n")
        existing_customer()

# %%
def television_support():
    print("\t\t\t\t\t:-------------TELEVISION SUPPORT-------------:")
    print("What is the nature of your problem?\n")
    print("\t\t\t[1] I can't access certain channels.\n\t\t\t[2] My picture is blurry.\n\t\t\t[3] I keep losing service.\n\t\t\t[4] Other issues.\n")
    try:
        tvUserChoice = int(input("\t\t >>>>> "))
        if tvUserChoice == 1:
            print("Please check the channel lists at DefinitelyNotSinister.com. If the channel you cannot access is there, please contact a live representative.")
            did_that_help()
        elif tvUserChoice == 2:
            print("Try adjusting the antenna above your television set.")
            did_that_help()
        elif tvUserChoice == 3:
            print("Is it raining outside? If so, wait until it is not raining and then try again.")
            did_that_help()
        elif tvUserChoice == 4:
            live_rep("support")
        else:
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~ Sorry, we didn't understand your selection. ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("Try again.....")
            existing_customer()
    except ValueError:
        print("\t\t\t\t\t\t\tSorry...Invalid request!!!\n\n")
        existing_customer()

# %%
def internet_support():
    print("\t\t\t\t\t:-------------INTERNET SUPPORT-------------:")
    print("\t\t\t[1] I can't connect to the internet.\n\t\t\t[2] My connection is very slow.\n\t\t\t[3] I can't access certain sites.\n\t\t\t[4] Other issues.\n")
    try:
        internetUserChoice = int(input("\t\t >>>>> "))
        if internetUserChoice == 1:
            print("Unplug your router, then plug it back in, then give it a good whack, like the Fonz.")
            did_that_help()
        elif internetUserChoice == 2:
            print("Make sure that all cell phones and other peoples computers are not connected to the internet, so that you can have all the bandwidth.")
            did_that_help()
        elif internetUserChoice == 3:
            print("Move to a different region or install a VPN. Some areas block certain sites.")
            did_that_help()
        elif internetUserChoice == 4:
            live_rep("support")
        else:
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~ Sorry, we didn't understand your selection. ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("Try again.....")
            internet_support()
    except ValueError:
        print("\t\t\t\t\t\t\tSorry...Invalid request!!!\n\n")
        internet_support()

# %%
def did_that_help():
    print("Did our solution solve your problem? (Yes/No)  \n")
    solveUserProb = input("\t\t >>>>> ")
    if solveUserProb.lower() == yes:
        print("Thankyou.....")
    if solveUserProb.lower() == no:
        print("\t\t\t[1] Talk to a live representative\n\t\t\t[2] Schedule a home visit \n")
        try:
            otherSolutionUser = input("\t\t >>>>> ")
            if otherSolutionUser == 1:
                live_rep("support")
            elif otherSolutionUser == 2:
                home_visit("support")
            else:
                print("~~~~~~~~~~~~~~~~~~~~~~~~~~~ Sorry, we didn't understand your selection. ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
                print("we have only these choices, sorry.....     try again.")
                did_that_help()
        except ValueError:
            print("\t\t\t\t\t\t\tSorry...Invalid request!!!\n\n")
            did_that_help()

# %%
def sign_up():
    print("Great choice, friend! We're excited to have you join the DNS family! Please select the package you are interested in signing up for.")
    print("\t\t\t[1] Bundle Deal (Internet + Cable)\n\t\t\t[2] Internet\n\t\t\t[3] Cable \n")
    try:
        signUser = int(input("\t\t >>>>>"))
        if signUser == 1:
            print("You've selected the Bundle Package! Please schedule a home visit and our technician will come and set up your new service.")
            home_visit("new install")
        elif signUser == 2:
            print("You've selected the Internet Only Package! Please schedule a home visit and our technician will come and set up your new service.")
            home_visit("new install")
        elif signUser == 3:
            print("You've selected the Cable Only Package! Please schedule a home visit and our technician will come and set up your new service.")
            home_visit("new install")
        else:
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~ Sorry, we didn't understand your selection. ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("Try again.....")
            sign_up()
    except ValueError:
        print("\t\t\t\t\t\t\tSorry...Invalid request!!!\n\n")
        sign_up()

# %%
def home_visit(purpose = None):
    if purpose is None:
        print("What is the purpose of home visit? \n")
        print("\t\t\t[1] New service installation.\n\t\t\t[2] Exisitng service repair.\n\t\t\t[3] Location scouting for unserviced region.\n")
        try:
            signUser = int(input("\t\t >>>>>"))
            if signUser == 1:
                print("Please enter a date below when you are available for a technician to come to your home and [PURPOSE SPECIFC TEXT HERE].\n")
                visit_date = input(" ")
                print("Wonderful! A technical will come visit you on",visit_date,". Please be available between the hours of 1:00 am and 11:00 pm.")
                home_visit("new install")
            elif signUser == 2:
                print("Please enter a date below when you are available for a technician to come to your home and [PURPOSE SPECIFC TEXT HERE].\n")
                visit_date = input(" ")
                print("Wonderful! A technical will come visit you on",visit_date,". Please be available between the hours of 1:00 am and 11:00 pm.")
                home_visit("support")
            elif signUser == 3:
                print("Please enter a date below when you are available for a technician to come to your home and [PURPOSE SPECIFC TEXT HERE].\n")
                visit_date = input(" ")
                print("Wonderful! A technical will come visit you on",visit_date,". Please be available between the hours of 1:00 am and 11:00 pm.")
                home_visit("scout")
            else:
                print("~~~~~~~~~~~~~~~~~~~~~~~~~~~ Sorry, we didn't understand your selection. ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
                print("Try again.....")
                home_visit()
            return visit_date
        except ValueError:
            print("\t\t\t\t\t\t\tSorry...Invalid request!!!\n\n")
            home_visit()

# %%
def live_rep(purpose):
    if purpose == "sales":
        print("Please hold while we connect you with a live sales representative. The wait time will be between two minutes and six hours. We thank you for your patience.\n")
    elif purpose == "support":
        print("Please hold while we connect you with a live support representative. The wait time will be between two minutes and six hours. We thank you for your patience.")

# %%
cs_service_bot()
# Out:
# Hello! Welcome to the DNS Cable Company's Service Portal. Are you a new or existing customer?
# [1] New Customer
# [2] Existing Customer
# Please enter the number corresponding to your choice: 1
#
#
#  :------     customer bot at your service     :--------
#
#
# We're excited to have you join the DNS family, how can we help you?
#
#
# 			[1] Sign up for service.
# 			[2] Schedule a home visit.
# 			[3] Speak to a sales representative.
# >>>>> 2
#
#
# What is the purpose of home visit?
#
# 			[1] New service installation.
# 			[2] Exisitng service repair.
# 			[3] Location scouting for unserviced region.
#
# 		 >>>>>1
# Please enter a date below when you are available for a technician to come to your home and [PURPOSE SPECIFC TEXT HERE].
#
#  2/3/2019
# Wonderful! A technical will come visit you on 2/3/2019 . Please be available between the hours of 1:00 am and 11:00 pm.
